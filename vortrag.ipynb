# %% [markdown]
# # Einleitung (Bastian)
#
# 1. Motivation: Post-Quantum Bedrohung
# 2. "Store Now, Decrypt Later"

# %% [markdown]
# # Theorie (Bastian)
#
# Zu finden unter [research](./research/)
#
# ### ECDH
#
# 1. Elliptische Kurven (falls noch nicht in VL behandelt)
#
# 2. X25519 (knappe Erklärung nur)
#
# ### Optional: Shor's Algorithm
#
# ### Kyber
#
# 1. Gitter
#
# 2. LWE
#
# 3. Kyber
#
# 4. ML-KEM

# %% [markdown]
# # Standards und Technologien (Maurice)
#
# 1. Open Quantum Safe (OQS)
# 2. Wireshark & TLS 1.3
# 3. OpenSSL

# %% [markdown]
# # Code & Setup (David)
#
# *Hinweis*: **David H.** und **Maurice P.** haben jeweils Benchmarks und Auswertungen parallel erarbeitet.
#
# Benchmarks sind zu finden unter [benchmarks](./benchmarks/) und [pqc-tesbench](./pqc-testbench/)
#
# 1. Code-Walkthrough & Docker-Aufbau
# 2. Metriken
# 3. Ergebnisse (nur zeigen, danach folgt Deutung)

# %% [markdown]
# # Auswertung (Maurice & David)
#
# [Ergebnisse](./benchmarks/results.json), [Boxplot](./benchmarks/benchmark_boxplot.png), [Säulendiagramm](./benchmarks/benchmark_plot.png)
#
# 1. Interpretieren der Ergebnisse (Verknüpfung Ergebnisse und Theorie)
# 2. Vergleich ECDH, Kyber und X25519Kyber768
# 3. Aussicht
